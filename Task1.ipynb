# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Reem Bin Omran**
# Himam

# %% [markdown]
# *I am interested in data science because it will help me to gain the needed technical skills for my current roll*

# %% [markdown]
# ### in cell number 5 i will try a simple caculation for practice purpeses only ###

# %%
100*5
# Out:
# 500

# %% [markdown]
# For this course i learned many things such as:
# - Data modeling
# - data management
# - Data Science Standard

# %% [markdown]
# ![social-media-audit-template.jpeg](attachment:f8d0d868-acbb-407d-b834-40e296c3795b.jpeg "Add Picture")

# %% [markdown]
# [click me](www.google.com "click here")

# %% [markdown]
# - [x] Task 1
# - [ ] Task 2
# - [x] Task 3
